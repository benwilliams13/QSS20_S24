# %%
## imports 
import pandas as pd
import numpy as np
import yaml
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# comment these out if you don't have plotnine--not essential here/only used once
import matplotlib.pyplot as plt
# import plotnine
# from plotnine import *

## way to connect to mysql 
## if you need to install
## uncomment this line:
#! pip install mysql-connector-python
import mysql.connector

## function to feed path name to load
## credentials
def load_creds(path: str):
    with open(path, 'r') as stream:
        try:
            creds = yaml.safe_load(stream)
        except yaml.YAMLError as exc:
            print(exc)
    return(creds)

pd.options.display.max_rows = 999
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # Preliminary: define connection and read sample of data

# %%
## read in creds; change the path name if stored
## elsewhere
creds = load_creds("09_db_cred.yaml")

# %%
creds
# Out:
# {'practice_database': {'user': 'qss20',
#   'password': 'xtPdDZHnxKMFSD5RyP',
#   'port': 3306,
#   'database': 'sentencing',
#   'host': 'qss20-7570-db.c.dartmouth.edu'}}

# %%
cnx = mysql.connector.connect(user=creds['practice_database']['user'], 
                            password=creds['practice_database']['password'],
                            port=creds['practice_database']['port'],
                            database= creds['practice_database']['database'],
                            host = creds['practice_database']['host'])
cnx

# %% [markdown]
# # Activity 1
#
# 1. Create a new column -- `in_chicago` when pulling from the `caseinit` table that takes on the value of "YES" if INCIDENT_CITY = Chicago; "NO" otherwise (which represents incidents in Cook County suburbs outside the city limits);  and pull the table. Use `crosstabs` to confirm that this worked
# 2. Repeat step 1 but also filter out blank strings (`INCIDENT_CITY` == "")
# 3. Use `where` to row filter to initiations in Chicago and use group by to find the count of cases diverted and not diverted (`is_in_diversion`); pull the table with those counts
# 4. Modify the query in step 3 to find the proportion of cases in chicago diverted (hint you made need to use case when in a subquery)
# 5. Modify the query in step 4 to find the proportion of cases in chicago versus cases not in chicago sent to diversion

# %%
# 1
compare_charge_city = """
SELECT *,
       CASE
         WHEN INCIDENT_CITY = "Chicago" THEN "YES"
         ELSE "NO"
       END AS in_chicago
FROM   caseinit
"""

read_sample_d = pd.read_sql_query(compare_charge_city, cnx)
read_sample_d
# Out:
#              CASE_ID  CASE_PARTICIPANT_ID           RECEIVED_DATE  \
# 0       198055620664          85937621020  08/15/1984 12:00:00 AM
# 1       198055620664          85937621020  08/15/1984 12:00:00 AM
# 2       198055620664          85937621020  08/15/1984 12:00:00 AM
# 3       198055620664          85937621020  08/15/1984 12:00:00 AM
# 4       198055620664          85937621020  08/15/1984 12:00:00 AM
# ...              ...                  ...                     ...
# 272289  597320386308         452719800958  07/18/2022 12:00:00 AM
# 272290  597328542979         452727325242  07/18/2022 12:00:00 AM
# 272291  597341166398         452739650297  07/19/2022 12:00:00 AM
# 272292  597341166398         452739650297  07/19/2022 12:00:00 AM
# 272293  597406808178         452817755138  07/23/2022 12:00:00 AM
#
#                       OFFENSE_CATEGORY PRIMARY_CHARGE_FLAG       CHARGE_ID  \
# 0                    PROMIS Conversion               False   1242195814523
# 1                    PROMIS Conversion               False   1242198287388
# 2                    PROMIS Conversion               False   1242351605056
# 3                    PROMIS Conversion               False   1242352841488
# 4                    PROMIS Conversion               False   1242356550787
# ...                                ...                 ...             ...
# 272289                    Retail Theft                True  11294724616133
# 272290  Aggravated Fleeing and Eluding                True  11295052270826
# 272291     Criminal Damage to Property                True  11295731072434
# 272292     Criminal Damage to Property                True  11295731072434
# 272293    UUW - Unlawful Use of Weapon                True  11310189917611
#
#         CHARGE_VERSION_ID                  DISPOSITION_CHARGED_OFFENSE_TITLE  \
# 0            155656315869                                FIRST DEGREE MURDER
# 1            131513547452                                      HOME INVASION
# 2            176626576281                                FIRST DEGREE MURDER
# 3            176617824190                                FIRST DEGREE MURDER
# 4            131238606761                                      HOME INVASION
# ...                   ...                                                ...
# 272289      1148300237684                                       RETAIL THEFT
# 272290      1148334245809  AGGRAVATED FLEEING OR ATTEMPT TO ELUDE A PEACE...
# 272291      1148405887926   CRIMINAL DAMAGE TO GOVERNMENT SUPPORTED PROPERTY
# 272292      1148405887926   CRIMINAL DAMAGE TO GOVERNMENT SUPPORTED PROPERTY
# 272293      1149901120181                  AGGRAVATED UNLAWFUL USE OF WEAPON
#
#         CHARGE_COUNT        DISPOSITION_DATE  ...  \
# 0                  2  12/17/2014 12:00:00 AM  ...
# 1                 14  12/17/2014 12:00:00 AM  ...
# 2                  4  12/17/2014 12:00:00 AM  ...
# 3                  5  12/17/2014 12:00:00 AM  ...
# 4                 13  12/17/2014 12:00:00 AM  ...
# ...              ...                     ...  ...
# 272289             1  09/02/2022 12:00:00 AM  ...
# 272290             1  09/06/2022 12:00:00 AM  ...
# 272291             1  08/23/2022 12:00:00 AM  ...
# 272292             1  08/23/2022 12:00:00 AM  ...
# 272293             1  08/31/2022 12:00:00 AM  ...
#
#                  LAW_ENFORCEMENT_AGENCY LAW_ENFORCEMENT_UNIT  \
# 0                   CHICAGO POLICE DEPT
# 1                   CHICAGO POLICE DEPT
# 2                   CHICAGO POLICE DEPT
# 3                   CHICAGO POLICE DEPT
# 4                   CHICAGO POLICE DEPT
# ...                                 ...                  ...
# 272289                       CHICAGO PD
# 272290                EVERGREEN PARK PD
# 272291  COOK COUNTY SHERIFF (IL0160000)
# 272292  COOK COUNTY SHERIFF (IL0160000)
# 272293                   PARK FOREST PD
#
#                    ARREST_DATE      FELONY_REVIEW_DATE FELONY_REVIEW_RESULT  \
# 0       08/15/1984 12:00:00 AM  08/15/1984 12:00:00 AM   Charge(S) Approved
# 1       08/15/1984 12:00:00 AM  08/15/1984 12:00:00 AM   Charge(S) Approved
# 2       08/15/1984 12:00:00 AM  08/15/1984 12:00:00 AM   Charge(S) Approved
# 3       08/15/1984 12:00:00 AM  08/15/1984 12:00:00 AM   Charge(S) Approved
# 4       08/15/1984 12:00:00 AM  08/15/1984 12:00:00 AM   Charge(S) Approved
# ...                        ...                     ...                  ...
# 272289  07/18/2022 09:20:00 AM  07/18/2022 12:00:00 AM             Approved
# 272290  07/18/2022 11:11:00 PM  07/18/2022 12:00:00 AM             Approved
# 272291                          08/02/2022 12:00:00 AM             Approved
# 272292                          08/02/2022 12:00:00 AM             Approved
# 272293  07/23/2022 05:09:00 AM  07/23/2022 12:00:00 AM             Approved
#
#               ARRAIGNMENT_DATE        UPDATED_OFFENSE_CATEGORY  \
# 0       09/21/1984 12:00:00 AM               PROMIS Conversion
# 1       09/21/1984 12:00:00 AM               PROMIS Conversion
# 2       09/21/1984 12:00:00 AM               PROMIS Conversion
# 3       09/21/1984 12:00:00 AM               PROMIS Conversion
# 4       09/21/1984 12:00:00 AM               PROMIS Conversion
# ...                        ...                             ...
# 272289  09/02/2022 12:00:00 AM                    Retail Theft
# 272290  09/06/2022 12:00:00 AM  Aggravated Fleeing and Eluding
# 272291  08/17/2022 12:00:00 AM     Criminal Damage to Property
# 272292  08/17/2022 12:00:00 AM     Criminal Damage to Property
# 272293  08/30/2022 12:00:00 AM    UUW - Unlawful Use of Weapon
#
#        is_in_diversion in_chicago in_chicago
# 0                False       None         NO
# 1                False       None         NO
# 2                False       None         NO
# 3                False       None         NO
# 4                False       None         NO
# ...                ...        ...        ...
# 272289            True       None        YES
# 272290           False       None         NO
# 272291           False       None        YES
# 272292           False       None        YES
# 272293           False       None         NO
#
# [272294 rows x 44 columns]

# %%
# 2
compare_charge_city = """
SELECT *,
       CASE
         WHEN INCIDENT_CITY = "Chicago" THEN "YES"
         ELSE "NO"
       END AS in_chicago
FROM   caseinit
WHERE INCIDENT_CITY <> ""
limit 5
"""

read_sample_d = pd.read_sql_query(compare_charge_city, cnx)
read_sample_d
# Out:
#         CASE_ID  CASE_PARTICIPANT_ID           RECEIVED_DATE  \
# 0  288677981683          95130773152  08/13/2006 12:00:00 AM
# 1  289906337472         103165877915  06/18/2007 12:00:00 AM
# 2  291517474172         103760942634  08/20/2008 12:00:00 AM
# 3  291824708774         103847218017  09/06/2008 12:00:00 AM
# 4  292499187771         103592823349  02/26/2010 12:00:00 AM
#
#     OFFENSE_CATEGORY PRIMARY_CHARGE_FLAG      CHARGE_ID  CHARGE_VERSION_ID  \
# 0  PROMIS Conversion                True  8889814596849       969426374459
# 1         Sex Crimes               False  6339673180732       590301665421
# 2  PROMIS Conversion                True  6363523969467       608781580816
# 3  PROMIS Conversion                True  6786219541928       701030496794
# 4  PROMIS Conversion                True  8223789049105       866910505404
#
#                    DISPOSITION_CHARGED_OFFENSE_TITLE  CHARGE_COUNT  \
# 0                            DUI LIC SUSP OR REVOKED             1
# 1                            CRIMINAL SEXUAL ASSAULT             5
# 2  AGGRAVATED FLEEING OR ATTEMPT TO ELUDE A PEACE...             1
# 3  AGGRAVATED DRIVING UNDER THE INFLUENCE OF ALCOHOL             1
# 4                           UNLAWFUL USE OF A WEAPON             1
#
#          DISPOSITION_DATE  ...    LAW_ENFORCEMENT_AGENCY LAW_ENFORCEMENT_UNIT  \
# 0  01/28/2015 12:00:00 AM  ...               OAK PARK PD
# 1  12/09/2013 12:00:00 AM  ...  HARVEY POLICE DEPARTMENT
# 2  01/18/2012 12:00:00 AM  ...           MORTON GROVE PD
# 3  07/11/2012 12:00:00 AM  ...                CHICAGO PD
# 4  08/22/2011 12:00:00 AM  ...       CHICAGO POLICE DEPT
#
#               ARREST_DATE      FELONY_REVIEW_DATE FELONY_REVIEW_RESULT  \
# 0  08/13/2006 02:53:00 AM  08/13/2006 12:00:00 AM   Charge(S) Approved
# 1  08/30/2011 02:00:00 PM  08/30/2011 12:00:00 AM             Approved
# 2  08/20/2008 12:00:00 AM  08/20/2008 12:00:00 AM  Approved Arrest War
# 3  09/06/2008 12:45:00 AM  09/06/2008 12:00:00 AM   Charge(S) Approved
# 4  02/25/2010 09:49:00 PM  02/26/2010 12:00:00 AM                   Sf
#
#          ARRAIGNMENT_DATE UPDATED_OFFENSE_CATEGORY is_in_diversion in_chicago  \
# 0  10/03/2012 12:00:00 AM        PROMIS Conversion           False       None
# 1  10/06/2011 12:00:00 AM               Sex Crimes           False       None
# 2  08/02/2010 12:00:00 AM        PROMIS Conversion           False       None
# 3  09/08/2011 12:00:00 AM        PROMIS Conversion           False       None
# 4  05/28/2010 12:00:00 AM        PROMIS Conversion           False       None
#
#   in_chicago
# 0         NO
# 1         NO
# 2         NO
# 3        YES
# 4        YES
#
# [5 rows x 44 columns]

# %%
# 3
compare_charge_city = """
SELECT
    COUNT(*) as count_div,
    is_in_diversion

FROM   caseinit
WHERE INCIDENT_CITY = "Chicago"
GROUP BY is_in_diversion
"""
read_sample_d = pd.read_sql_query(compare_charge_city, cnx)
read_sample_d
# Out:
#    count_div is_in_diversion
# 0     167171           False
# 1       6402            True

# %%
# 4

compare_charge_city = """
SELECT
                *
                CASE
                    WHEN is_in_diversion = "True" THEN 1
                    ELSE 0
                END  is_div_bool
            FROM caseinit
# Out:
#   Cell In[28], line 3
#     compare_charge_city = """
#                           ^
# SyntaxError: incomplete input

# %%
# your code here 1

chicago_var = """
SELECT *,
       CASE
         WHEN INCIDENT_CITY = "Chicago" THEN 'YES'
         ELSE 'NO'
       END AS in_chicago
FROM   caseinit 
where INCIDENT_CITY != ""
limit 5
"""
read_sample_d = pd.read_sql_query(chicago_var, cnx)
read_sample_d
# Out:
#         CASE_ID  CASE_PARTICIPANT_ID           RECEIVED_DATE  \
# 0  288677981683          95130773152  08/13/2006 12:00:00 AM
# 1  289906337472         103165877915  06/18/2007 12:00:00 AM
# 2  291517474172         103760942634  08/20/2008 12:00:00 AM
# 3  291824708774         103847218017  09/06/2008 12:00:00 AM
# 4  292499187771         103592823349  02/26/2010 12:00:00 AM
#
#     OFFENSE_CATEGORY PRIMARY_CHARGE_FLAG      CHARGE_ID  CHARGE_VERSION_ID  \
# 0  PROMIS Conversion                True  8889814596849       969426374459
# 1         Sex Crimes               False  6339673180732       590301665421
# 2  PROMIS Conversion                True  6363523969467       608781580816
# 3  PROMIS Conversion                True  6786219541928       701030496794
# 4  PROMIS Conversion                True  8223789049105       866910505404
#
#                    DISPOSITION_CHARGED_OFFENSE_TITLE  CHARGE_COUNT  \
# 0                            DUI LIC SUSP OR REVOKED             1
# 1                            CRIMINAL SEXUAL ASSAULT             5
# 2  AGGRAVATED FLEEING OR ATTEMPT TO ELUDE A PEACE...             1
# 3  AGGRAVATED DRIVING UNDER THE INFLUENCE OF ALCOHOL             1
# 4                           UNLAWFUL USE OF A WEAPON             1
#
#          DISPOSITION_DATE  ...    LAW_ENFORCEMENT_AGENCY LAW_ENFORCEMENT_UNIT  \
# 0  01/28/2015 12:00:00 AM  ...               OAK PARK PD
# 1  12/09/2013 12:00:00 AM  ...  HARVEY POLICE DEPARTMENT
# 2  01/18/2012 12:00:00 AM  ...           MORTON GROVE PD
# 3  07/11/2012 12:00:00 AM  ...                CHICAGO PD
# 4  08/22/2011 12:00:00 AM  ...       CHICAGO POLICE DEPT
#
#               ARREST_DATE      FELONY_REVIEW_DATE FELONY_REVIEW_RESULT  \
# 0  08/13/2006 02:53:00 AM  08/13/2006 12:00:00 AM   Charge(S) Approved
# 1  08/30/2011 02:00:00 PM  08/30/2011 12:00:00 AM             Approved
# 2  08/20/2008 12:00:00 AM  08/20/2008 12:00:00 AM  Approved Arrest War
# 3  09/06/2008 12:45:00 AM  09/06/2008 12:00:00 AM   Charge(S) Approved
# 4  02/25/2010 09:49:00 PM  02/26/2010 12:00:00 AM                   Sf
#
#          ARRAIGNMENT_DATE UPDATED_OFFENSE_CATEGORY is_in_diversion in_chicago  \
# 0  10/03/2012 12:00:00 AM        PROMIS Conversion           False       None
# 1  10/06/2011 12:00:00 AM               Sex Crimes           False       None
# 2  08/02/2010 12:00:00 AM        PROMIS Conversion           False       None
# 3  09/08/2011 12:00:00 AM        PROMIS Conversion           False       None
# 4  05/28/2010 12:00:00 AM        PROMIS Conversion           False       None
#
#   in_chicago
# 0         NO
# 1         NO
# 2         NO
# 3        YES
# 4        YES
#
# [5 rows x 44 columns]

# %%
# your code here 2


chicago_var = """
SELECT *,
       CASE
           WHEN INCIDENT_CITY = 'Chicago' THEN 'YES'
           ELSE 'NO'
       END AS in_chicago
FROM caseinit
WHERE INCIDENT_CITY <> '';
limit 5
"""
read_sample_d = pd.read_sql_query(chicago_var, cnx)
read_sample_d
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/mysql/connector/cursor.py:748, in MySQLCursor.execute(self, operation, params, multi)
#     747 try:
# --> 748     self._handle_result(self._connection.cmd_query(stmt))
#     749 except InterfaceError as err:
#
# File /opt/anaconda3/lib/python3.11/site-packages/mysql/connector/opentelemetry/context_propagation.py:74, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      73 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 74     return method(cnx, *args, **kwargs)
#      76 current_span = trace.get_current_span()
#
# File /opt/anaconda3/lib/python3.11/site-packages/mysql/connector/connection.py:865, in MySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     864 if self._have_next_result:
# --> 865     raise InterfaceError(
#     866         "Use cmd_query_iter for statements with multiple queries."
#     867     )
#     869 return result
#
# InterfaceError: Use cmd_query_iter for statements with multiple queries.
#
# The above exception was the direct cause of the following exception:
#
# InterfaceError                            Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:2262, in SQLiteDatabase.execute(self, sql, params)
#    2261 try:
# -> 2262     cur.execute(sql, *args)
#    2263     return cur
#
# File /opt/anaconda3/lib/python3.11/site-packages/mysql/connector/cursor.py:751, in MySQLCursor.execute(self, operation, params, multi)
#     750 if self._connection.have_next_result:
# --> 751     raise InterfaceError(
#     752         "Use multi=True when executing multiple statements"
#     753     ) from err
#     754 raise
#
# InterfaceError: Use multi=True when executing multiple statements
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:2266, in SQLiteDatabase.execute(self, sql, params)
#    2265 try:
# -> 2266     self.con.rollback()
#    2267 except Exception as inner_exc:  # pragma: no cover
#
# File /opt/anaconda3/lib/python3.11/site-packages/mysql/connector/connection.py:1290, in MySQLConnection.rollback(self)
#    1288     self.get_rows()
# -> 1290 self._execute_query("ROLLBACK")
#
# File /opt/anaconda3/lib/python3.11/site-packages/mysql/connector/connection.py:1302, in MySQLConnection._execute_query(self, query)
#    1301 self.handle_unread_result()
# -> 1302 self.cmd_query(query)
#
# File /opt/anaconda3/lib/python3.11/site-packages/mysql/connector/opentelemetry/context_propagation.py:74, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      73 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 74     return method(cnx, *args, **kwargs)
#      76 current_span = trace.get_current_span()
#
# File /opt/anaconda3/lib/python3.11/site-packages/mysql/connector/connection.py:855, in MySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     854 try:
# --> 855     result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     856 except ProgrammingError as err:
#
# File /opt/anaconda3/lib/python3.11/site-packages/mysql/connector/connection.py:631, in MySQLConnection._handle_result(self, packet)
#     630 if packet[4] == 255:
# --> 631     raise get_exception(packet)
#     633 # We have a text result set
#
# ProgrammingError: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'limit 5' at line 1
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[14], line 14
#       1 # your code here 2
#       4 chicago_var = """
#       5 SELECT *,
#       6        CASE
#    (...)
#      12 limit 5
#      13 """
# ---> 14 read_sample_d = pd.read_sql_query(chicago_var, cnx)
#      15 read_sample_d
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:486, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     483 assert dtype_backend is not lib.no_default
#     485 with pandasSQL_builder(con) as pandas_sql:
# --> 486     return pandas_sql.read_query(
#     487         sql,
#     488         index_col=index_col,
#     489         params=params,
#     490         coerce_float=coerce_float,
#     491         parse_dates=parse_dates,
#     492         chunksize=chunksize,
#     493         dtype=dtype,
#     494         dtype_backend=dtype_backend,
#     495     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:2326, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2315 def read_query(
#    2316     self,
#    2317     sql,
#    (...)
#    2324     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2325 ) -> DataFrame | Iterator[DataFrame]:
# -> 2326     cursor = self.execute(sql, params)
#    2327     columns = [col_desc[0] for col_desc in cursor.description]
#    2329     if chunksize is not None:
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:2271, in SQLiteDatabase.execute(self, sql, params)
#    2267 except Exception as inner_exc:  # pragma: no cover
#    2268     ex = DatabaseError(
#    2269         f"Execution failed on sql: {sql}\n{exc}\nunable to rollback"
#    2270     )
# -> 2271     raise ex from inner_exc
#    2273 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
#    2274 raise ex from exc
#
# DatabaseError: Execution failed on sql:
# SELECT *,
#        CASE
#            WHEN INCIDENT_CITY = 'Chicago' THEN 'YES'
#            ELSE 'NO'
#        END AS in_chicago
# FROM caseinit
# WHERE INCIDENT_CITY <> '';
# limit 5
#
# Use multi=True when executing multiple statements
# unable to rollback

# %%
# your code here 3

chicago_var = """
SELECT updated_offense_category,
       Count(*) AS count_offense
FROM   caseinit
WHERE  race IN ( "black", "white" )
GROUP  BY updated_offense_category
ORDER  BY count_offense DESC
LIMIT  5 
"""


t5_d = pd.read_sql_query(t5, cnx)
t5_d

# %%
# your code here 4

# %%
# your code here 5

# %% [markdown]
# # Activity 2
#
# 1. Use the following crosswalk and the `CASE` variable in the `divert` table to create a new variable `DIVERSION_PROGRAM_TEXT` that spells out the diversion programs
#     - DC: Drug Court
#
#     - DDPP: Drug Deferred Prosecution
#
#     - DS: Drug School
#
#     - RJCC: Restorative Justice
#
#     - MHC: Mental Health Court
#
#     - VC: Veteran Court
#
# 2. Build on the query from step 1 to filter to Narcotics as the `UPDATED_OFFENSE_CATEGORY` and Black or White defendants (based on race in the diversions table) (hint: you'll need to join with the caseinit table based on case_id and case_participant_id, you can do a inner join to keep only those diverted). Select the case_id, case_participant_id, case, race, and diversion_program_text columns

# %%
# your code here 1

# %%
# your code here 2
